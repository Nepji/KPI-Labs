# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

df_incidents = pd.read_csv('data/Police_Department_Incidents_-_Previous_Year__2016_.csv')
limit = 1000
df_incidents = df_incidents.iloc[0:limit, :]
df_incidents.shape

latitude = 37.77
longitude = -122.42

sanfran_map = folium.Map(location = [latitude, longitude], zoom_start = 12)
incidents = folium.map.FeatureGroup()

for lat, lng, in zip(df_incidents.Y, df_incidents.X):
    incidents.add_child(folium.features.CircleMarker(
    [lat, lng], radius = 5, color = "yellow", fill_color = "red", fill_opacity=0.6))

sanfran_map.add_child(incidents)
sanfran_map = folium.Map(location =[latitude, longitude], zoom_start = 12)
incidents = MarkerCluster().add_to(sanfran_map)

for lat, lng, label, in zip(df_incidents.Y, df_incidents.X, df_incidents.Category):
    folium.Marker(location = [lat, lng], icon = None, popup = label).add_to(incidents)

sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b498095f0934640732f02d6f0680f367 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b498095f0934640732f02d6f0680f367&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b498095f0934640732f02d6f0680f367 = L.map(
#                 &quot;map_b498095f0934640732f02d6f0680f367&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0de5c8d96018a48ed5270fb8ed2180bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0de5c8d96018a48ed5270fb8ed2180bf.addTo(map_b498095f0934640732f02d6f0680f367);
#
#
#             var marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_b54dd484193e39949f62c3d9d5242182 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58);
#
#
#         var popup_5e6803eaf1c383a86e02652935643430 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18f891bbac611625411b2716425ec199 = $(`&lt;div id=&quot;html_18f891bbac611625411b2716425ec199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_5e6803eaf1c383a86e02652935643430.setContent(html_18f891bbac611625411b2716425ec199);
#
#
#
#         marker_b54dd484193e39949f62c3d9d5242182.bindPopup(popup_5e6803eaf1c383a86e02652935643430)
#         ;
#
#
#
#
#             var marker_13c1bf254650d1a1aef3f3a01d3f34f9 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58);
#
#
#         var popup_87bf7b098de5cab18caa4b71f6693193 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6bdca654a5a02b172dedb9ee9285262 = $(`&lt;div id=&quot;html_d6bdca654a5a02b172dedb9ee9285262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_87bf7b098de5cab18caa4b71f6693193.setContent(html_d6bdca654a5a02b172dedb9ee9285262);
#
#
#
#         marker_13c1bf254650d1a1aef3f3a01d3f34f9.bindPopup(popup_87bf7b098de5cab18caa4b71f6693193)
#         ;
#
#
#
#
#             var marker_cfd7073b61040009989a3d0c26828a5d = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58);
#
#
#         var popup_f4d25782bd01de83b3827bc249b16561 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d2f439239f4a39a0bf5b52e0c277538 = $(`&lt;div id=&quot;html_9d2f439239f4a39a0bf5b52e0c277538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_f4d25782bd01de83b3827bc249b16561.setContent(html_9d2f439239f4a39a0bf5b52e0c277538);
#
#
#
#         marker_cfd7073b61040009989a3d0c26828a5d.bindPopup(popup_f4d25782bd01de83b3827bc249b16561)
#         ;
#
#
#
#
#             var marker_96927bcb05577efbb379dc251a24db3c = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58);
#
#
#         var popup_284824de6857e78143c061a5cbcbfeaa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd8604c94f8b63b0dd192087a2715f53 = $(`&lt;div id=&quot;html_bd8604c94f8b63b0dd192087a2715f53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_284824de6857e78143c061a5cbcbfeaa.setContent(html_bd8604c94f8b63b0dd192087a2715f53);
#
#
#
#         marker_96927bcb05577efbb379dc251a24db3c.bindPopup(popup_284824de6857e78143c061a5cbcbfeaa)
#         ;
#
#
#
#
#             var marker_991725656998dc8beff6369655a77ee7 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(marker_cluster_d3c38b1f0edea99d86ec392a71ca9a58);
#
#
#         var popup_86b1116229b12d1408ec0a73e53b7ff5 = L.popup({&quot;maxWidth&quot;: &quot;10
